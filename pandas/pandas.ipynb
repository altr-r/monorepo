# %%
# importing pandas, pd is an alias
import pandas as pd

# %%
# read_csv converts any csv file into a dataframe
df = pd.read_csv("./Corona_NLP_Train.csv")
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
# .head() method prints the first 5 entries of the database
# it can take integer argument, for example if 10 was given as argument of head()
# it would've returned the first 10 entries instead
df.head()
df.head(10)
# Out:
#    UserName  ScreenName                   Location     TweetAt  \
# 0      3799       48751                     London  16-03-2020
# 1      3800       48752                         UK  16-03-2020
# 2      3801       48753                  Vagabonds  16-03-2020
# 3      3802       48754                        NaN  16-03-2020
# 4      3803       48755                        NaN  16-03-2020
# 5      3804       48756  ÃT: 36.319708,-82.363649  16-03-2020
# 6      3805       48757       35.926541,-78.753267  16-03-2020
# 7      3806       48758                    Austria  16-03-2020
# 8      3807       48759            Atlanta, GA USA  16-03-2020
# 9      3808       48760           BHAVNAGAR,GUJRAT  16-03-2020
#
#                                        OriginalTweet           Sentiment
# 0  @MeNyrbie @Phil_Gahan @Chrisitv https://t.co/i...             Neutral
# 1  advice Talk to your neighbours family to excha...            Positive
# ...

# %%
# .tail() does what .head() does but from the end of the dataframe
df.tail()
# Out:
#        UserName  ScreenName                      Location     TweetAt  \
# 41152     44951       89903  Wellington City, New Zealand  14-04-2020
# 41153     44952       89904                           NaN  14-04-2020
# 41154     44953       89905                           NaN  14-04-2020
# 41155     44954       89906                           NaN  14-04-2020
# 41156     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# 41152  Airline pilots offering to stock supermarket s...             Neutral
# 41153  Response to complaint not provided citing COVI...  Extremely Negative
# 41154  You know itÂs getting tough when @KameronWild...            Positive
# 41155  Is it wrong that the smell of hand sanitizer i...             Neutral
# 41156  @TartiiCat Well new/used Rift S are going for ...            Negative

# %%
# returns a tuple consisting of the number of rows and columns
# it is an attribute not a method
df.shape
# Out:
# (41157, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41157 entries, 0 to 41156
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41157 non-null  int64
#  1   ScreenName     41157 non-null  int64
#  2   Location       32567 non-null  str
#  3   TweetAt        41157 non-null  str
#  4   OriginalTweet  41157 non-null  str
#  5   Sentiment      41157 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 1.9 MB

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
import numpy as np
mylist = list('abcedfghijklmnopqrstuvwxyz')
myarr = np.arange(26)
mydict = dict(zip(mylist, myarr))

# %%
list_series = pd.Series(mylist)
arr_series = pd.Series(myarr)
dict_series = pd.Series(mydict)

dict_series.head()
# Out:
# a    0
# b    1
# c    2
# e    3
# d    4
# dtype: int64

# %%
df = dict_series.to_frame().reset_index()

df
# Out:
#    index   0
# 0      a   0
# 1      b   1
# 2      c   2
# 3      e   3
# 4      d   4
# 5      f   5
# 6      g   6
# 7      h   7
# 8      i   8
# 9      j   9
# 10     k  10
# 11     l  11
# 12     m  12
# 13     n  13
# 14     o  14
# 15     p  15
# 16     q  16
# 17     r  17
# 18     s  18
# 19     t  19
# 20     u  20
# 21     v  21
# 22     w  22
# 23     x  23
# 24     y  24
# 25     z  25
